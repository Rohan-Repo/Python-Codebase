# %% [markdown]
# ### Supress Warnings

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in c:\swares\exploded\python_3_12\lib\site-packages (from -r requirements.txt (line 1)) (2.3.3)
# Requirement already satisfied: pandas in c:\swares\exploded\python_3_12\lib\site-packages (from -r requirements.txt (line 2)) (2.3.3)
# Requirement already satisfied: matplotlib in c:\swares\exploded\python_3_12\lib\site-packages (from -r requirements.txt (line 3)) (3.10.6)
# Requirement already satisfied: seaborn in c:\swares\exploded\python_3_12\lib\site-packages (from -r requirements.txt (line 4)) (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\swares\exploded\python_3_12\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\swares\exploded\python_3_12\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\swares\exploded\python_3_12\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\swares\exploded\python_3_12\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\swares\exploded\python_3_12\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\swares\exploded\python_3_12\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\swares\exploded\python_3_12\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\swares\exploded\python_3_12\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (24.2)
# Requirement already satisfied: pillow>=8 in c:\swares\exploded\python_3_12\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\swares\exploded\python_3_12\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (3.2.5)
# Requirement already satisfied: six>=1.5 in c:\swares\exploded\python_3_12\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 2)) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_2 = pd.read_csv(
    'coffee_shop_transactions_cleaned.csv',
    parse_dates = ['DateTime']   # parse_dates → converts the column to datetime64 on load
                                 # without this, DateTime loads as plain text (string)
                                 # and .dt.date / .dt.hour will throw AttributeError
)

print('\n Number of Rows,Cols : ', df_2.shape)
print('\n DateTime dtype      :', df_2['DateTime'].dtype)  # should be datetime64[ns]

df_2
# Out:
#  Number of Rows,Cols :  (21, 7)
#
#  DateTime dtype      : datetime64[ns]
#    TransactionID            DateTime        Item  PricePerItem  Quantity  \
# 0         TX1001 2025-09-08 08:15:23  Cappuccino           4.2         1
# 1         TX1002 2025-09-01 08:22:11       Latte           4.8         2
# 2         TX1003 2025-09-12 08:35:46    Espresso           3.3         1
# 3         TX1004 2025-09-03 08:50:39   Croissant           3.0         1
# 4         TX1006 2025-09-02 09:05:55       Mocha           5.1         1
# 5         TX1007 2025-09-15 09:15:08         Tea           2.7         1
# 6         TX1008 2025-09-05 09:30:42       Latte           4.8         1
# 7         TX1009 2025-09-04 09:45:14       Bagel           3.3         1
# 8         TX1010 2025-09-10 10:00:27  Cappuccino           4.2         2
# 9         TX1011 2025-09-18 10:15:50    Espresso           3.3         1
# 10        TX1013 2025-09-06 10:45:34       Mocha           5.1         2
# 11        TX1015 2025-09-14 11:15:51   Croissant           3.0         1
# 12        TX1016 2025-09-11 11:30:45       Latte           4.8         1
# 13        TX1017 2025-09-13 11:45:29  Cappuccino           4.2         2
# 14        TX1019 2025-09-17 12:15:59         Tea           2.7         1
# 15        TX1020 2025-09-19 12:30:12   Americano           3.6         1
# 16        TX1021 2025-09-20 12:45:36  Cappuccino           4.2         1
# 17        TX1022 2025-09-22 13:00:28       Latte           4.8         2
# 18        TX1023 2025-09-23 13:15:17      Muffin           3.3         1
# 19        TX1025 2025-09-25 13:45:31    Espresso           3.3         1
# 20        TX1026 2025-09-26 14:00:09       Latte           4.8         1
#
#     TotalPrice PaymentMethod
# 0          4.2   Credit Card
# 1          9.6          Cash
# 2          3.3    Mobile Pay
# 3          3.0   Credit Card
# 4          5.1    Mobile Pay
# 5          2.7   Credit Card
# 6          4.8    Mobile Pay
# 7          3.3          Cash
# 8          8.4   Credit Card
# 9          3.3          Cash
# 10        10.2    Mobile Pay
# 11         3.0   Credit Card
# 12         4.8   Credit Card
# 13         8.4          Cash
# 14         2.7   Credit Card
# 15         3.6          Cash
# 16         4.2   Credit Card
# 17         9.6    Mobile Pay
# 18         3.3          Cash
# 19         3.3   Credit Card
# 20         4.8          Cash

# %%
from IPython.display import Image

# %%
Image(url="Coffee-Shop-EDA-Charts-1.jpg")
# Out:
# <img src="Coffee-Shop-EDA-Charts-1.jpg"/>

# %%
Image(url="Coffee-Shop-EDA-Charts-2.jpg")
# Out:
# <img src="Coffee-Shop-EDA-Charts-2.jpg"/>

# %% [markdown]
# ***

# %% [markdown]
# ## 📊 Section 3 — Exploratory Data Analysis (EDA)
#
# | # | Analysis | Pandas / Seaborn / Matplotlib method used |
# |---|---|---|
# | 1 | Dataset Snapshot | `.describe()` `.nunique()` `.sum()` |
# | 2 | Items Ordered | `value_counts()` → `sns.barplot` |
# | 3 | Revenue by Item | `groupby` + `sum()` → `sns.barplot` (horizontal) |
# | 4 | Payment Method Split | `value_counts()` → `axes[0].pie` + `sns.barplot` |
# | 5 | Daily Revenue Trend | `.dt.date` + `groupby` → `sns.lineplot` |
# | 6 | Busiest Hours | `.dt.hour` → `sns.countplot` |
# | 7 | Order Value Distribution | `sns.histplot(kde=True)` + `sns.boxplot` |
# | 8 | Correlation Heatmap | `.corr()` → `sns.heatmap(annot=True)` |
# | 9 | Key Insights Summary | `groupby` + `idxmax()` |

# %% [markdown]
# ### Set Global style — applies to all charts below

# %%
# sns.set_theme(style='whitegrid', palette='pastel', context='talk')
# sns.set_theme(style='darkgrid', palette='muted', context='notebook')
# sns.set_theme(style='whitegrid', palette='deep', context='notebook')
sns.set_theme(style='darkgrid', palette='deep', context='notebook')

# %% [markdown]
# #### 1️⃣ Dataset Snapshot
# > Quick numbers before we plot anything.

# %%
print(f'Rows              : {len(df_2)}')
print(f'Unique items      : {sorted(df_2["Item"].unique())}')
print(f'Payment methods   : {sorted(df_2["PaymentMethod"].unique())}')
print(f'Total revenue     : ${df_2["TotalPrice"].sum():.2f}')
print(f'Avg order value   : ${df_2["TotalPrice"].mean():.2f}')
print()
df_2[['PricePerItem','Quantity','TotalPrice']].describe().round(2)
# Out:
# Rows              : 21
# Unique items      : ['Americano', 'Bagel', 'Cappuccino', 'Croissant', 'Espresso', 'Latte', 'Mocha', 'Muffin', 'Tea']
# Payment methods   : ['Cash', 'Credit Card', 'Mobile Pay']
# Total revenue     : $105.60
# Avg order value   : $5.03
#        PricePerItem  Quantity  TotalPrice
# count         21.00     21.00       21.00
# mean           3.93      1.24        5.03
# std            0.83      0.44        2.54
# min            2.70      1.00        2.70
# 25%            3.30      1.00        3.30
# 50%            4.20      1.00        4.20
# 75%            4.80      1.00        5.10
# max            5.10      2.00       10.20

# %% [markdown]
# #### 2️⃣ How Many Times Was Each Item Ordered?
# > `value_counts()` counts rows per item.
# > `sns.barplot` draws it with one line.

# %% [markdown]
# #### We use a bar chart because we are comparing the number of orders for different items. The height of each bar makes it easy to see which item is the most or least popular.

# %%
# value_counts() — counts how many times each item appears in the Item column
item_counts = df_2['Item'].value_counts().reset_index()
item_counts.columns = ['Item', 'Orders']   # rename columns for clarity

plt.figure(
    figsize=(9, 4)    # width=9 inches, height=4 inches
)

sns.barplot(
    data     = item_counts,  # DataFrame to use
    x        = 'Item',       # column for the x-axis (categories)
    y        = 'Orders',     # column for the y-axis (bar height)
    palette  = 'Blues_d'     # colour palette — dark-to-light blue gradient
)

plt.title('Number of Orders per Item')  # chart heading
plt.xticks(rotation=15)                 # tilt x-axis labels 15° so they don't overlap
plt.tight_layout()                      # auto-adjust spacing so nothing is clipped
plt.show()                              # render the chart

# %% [markdown]
# #### 3️⃣ Total Revenue by Item
# > `groupby` + `sum()` then `sns.barplot` with `orient='h'` for a horizontal layout.

# %% [markdown]
# #### We use a horizontal bar chart because we want to rank items by revenue. The longer the bar, the more revenue that item generated.

# %%
# groupby('Item') — group all rows that share the same item name
# ['TotalPrice'].sum() — add up TotalPrice within each group
# reset_index() — converts the result back into a normal DataFrame
rev = df_2.groupby('Item')['TotalPrice'].sum().reset_index()
rev = rev.sort_values('TotalPrice', ascending=False)  # highest revenue first

plt.figure(
    figsize=(9, 5)    # width=9 inches, height=5 inches
)

sns.barplot(
    data     = rev,          # DataFrame to use
    y        = 'Item',       # y-axis = categories → makes the bar horizontal
    x        = 'TotalPrice', # x-axis = bar length (revenue amount)
    palette  = 'Blues_d'     # dark-to-light blue gradient
)

plt.title('Total Revenue by Item')  # chart heading
plt.xlabel('Revenue ($)')           # label on the x-axis
plt.tight_layout()                  # prevent labels being cut off
plt.show()

# %% [markdown]
# #### 4️⃣ Payment Method Split
# > Pie chart (matplotlib) for share of transactions.
# > `sns.barplot` for revenue per method.

# %% [markdown]
# #### We use a pie chart because we want to show how transactions are divided among payment methods. Each slice represents a percentage of the whole.

# %% [markdown]
# #### We use a bar chart because we want to compare revenue amounts. Bar lengths make it easier to see which payment method generated more money.

# %%
pay_count   = df_2['PaymentMethod'].value_counts()                               # count transactions per method
pay_revenue = df_2.groupby('PaymentMethod')['TotalPrice'].sum().reset_index()    # total revenue per method

fig, axes = plt.subplots(
    1, 2,             # 1 row, 2 columns — two charts side by side
    figsize=(12, 4)   # total figure width=12, height=4
)

# ── Left chart: Pie ────────────────────────────────────────────────────
axes[0].pie(
    pay_count.values,                    # numeric values that define slice sizes
    labels      = pay_count.index,       # label each slice with the payment method name
    autopct     = '%1.1f%%',             # show percentage inside each slice (1 decimal)
    startangle  = 140,                   # rotate the first slice to 140° (looks balanced)
    colors      = sns.color_palette('pastel')  # soft pastel colours from seaborn
)
axes[0].set_title('Transaction Share by Payment Method')

# ── Right chart: Bar ───────────────────────────────────────────────────
sns.barplot(
    data     = pay_revenue,      # DataFrame with payment method + revenue
    x        = 'PaymentMethod',  # x-axis categories
    y        = 'TotalPrice',     # bar height = revenue
    palette  = 'pastel',         # soft colour palette
    ax       = axes[1]           # draw into the RIGHT subplot (index 1)
)
axes[1].set_title('Revenue by Payment Method')
axes[1].set_xlabel('Method')
axes[1].set_ylabel('Revenue ($)')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 5️⃣ Daily Revenue Trend
# > `.dt.date` extracts just the date from `DateTime`.
# > `sns.lineplot` draws the trend with markers.

# %% [markdown]
# #### We use a line chart because dates occur in order. Connecting the points helps us see trends and whether revenue is increasing or decreasing.

# %%
# .dt.date — extracts just the date part (no time) from a DateTime column
df_2['Date'] = df_2['DateTime'].dt.date

# groupby('Date') — one row per day; sum TotalPrice for that day
daily = df_2.groupby('Date')['TotalPrice'].sum().reset_index()

plt.figure(
    figsize=(11, 4)   # wide figure suits a time series
)

sns.lineplot(
    data    = daily,        # DataFrame with Date and TotalPrice columns
    x       = 'Date',       # x-axis = date (time axis)
    y       = 'TotalPrice', # y-axis = revenue value
    marker  = 'o',          # place a circle marker at each data point
    color   = 'steelblue'   # line and marker colour
)

plt.title('Daily Revenue — September 2025')
plt.xlabel('Date')
plt.ylabel('Revenue ($)')
plt.xticks(rotation=45)  # tilt dates 45° so they don't overlap
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 6️⃣ Busiest Hours
# > `.dt.hour` extracts the hour.
# > `sns.countplot` counts transactions per hour automatically — no manual groupby needed.

# %% [markdown]
# #### We use a count plot because we want to count how many transactions happened during each hour of the day.

# %%
# .dt.hour — extracts the hour (0–23) from a DateTime column
df_2['Hour'] = df_2['DateTime'].dt.hour

plt.figure(
    figsize=(9, 4)   # width=9, height=4
)

sns.countplot(
    data     = df_2,     # full DataFrame — countplot counts rows automatically
    x        = 'Hour',   # count how many rows exist for each unique hour value
    palette  = 'Blues_d' # dark-to-light blue gradient per bar
    # NOTE: no need for groupby — countplot does the counting internally
)

plt.title('Transactions by Hour of Day')
plt.xlabel('Hour')
plt.ylabel('Transactions')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 7️⃣ Order Value Distribution
# > `sns.histplot` with `kde=True` adds a smooth curve on top of the histogram.
# > `sns.boxplot` shows spread and outliers per item.

# %% [markdown]
# #### We use a histogram because we want to see how order totals are distributed. It shows whether most orders are small, medium, or large.
# - The KDE line gives us a smooth view of the distribution and helps us understand where most values are concentrated.

# %% [markdown]
# #### We use a box plot because it summarizes the distribution of prices for each item and helps us detect outliers and variability.

# %%
fig, axes = plt.subplots(
    1, 2,             # 1 row, 2 columns
    figsize=(13, 4)   # wide to fit both charts comfortably
)

# ── Left: Histogram with KDE curve ────────────────────────────────────
sns.histplot(
    df_2['TotalPrice'],  # the data series to plot
    bins    = 10,        # split the range into 10 equal-width buckets
    kde     = True,      # overlay a smooth KDE (kernel density estimate) curve
    color   = 'steelblue', # bar fill colour
    ax      = axes[0]    # draw into the LEFT subplot
)
axes[0].set_title('Distribution of Order Totals')
axes[0].set_xlabel('Total Price ($)')

# ── Right: Box plot per item ───────────────────────────────────────────
sns.boxplot(
    data     = df_2,          # full DataFrame
    x        = 'Item',        # one box drawn per unique item
    y        = 'TotalPrice',  # values inside each box = TotalPrice for that item
    palette  = 'pastel',      # soft colour per box
    ax       = axes[1]        # draw into the RIGHT subplot
    # Box shows: median (centre line), IQR (box), whiskers (1.5×IQR), outliers (dots)
)
axes[1].set_title('Price Spread per Item')
axes[1].tick_params(
    axis     = 'x',   # only affect the x-axis tick labels
    rotation = 20     # tilt labels 20° to avoid overlap
)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 8️⃣ Correlation Heatmap
# > `.corr()` measures how strongly numeric columns move together.
# > `sns.heatmap` with `annot=True` prints the values inside each cell automatically.

# %% [markdown]
# #### We use a heatmap because colors make correlations easy to interpret. Strong positive relationships appear in one color, negative relationships in another, and values near zero indicate little or no relationship.

# %%
# .corr() — computes pairwise correlation between numeric columns
# Values range from -1 (perfect negative) to +1 (perfect positive), 0 = no link
corr = df_2[['PricePerItem','Quantity','TotalPrice']].corr().round(2)
print(corr)

plt.figure(
    figsize=(6, 4)   # small square figure suits a 3×3 grid
)

sns.heatmap(
    corr,               # the correlation matrix (DataFrame)
    annot      = True,  # print the numeric value inside each cell
    fmt        = '.2f', # format the annotation to 2 decimal places
    cmap       = 'coolwarm',  # red = positive correlation, blue = negative
    linewidths = 0.5,   # thin white grid lines between cells
    vmin       = -1,    # anchor the colour scale minimum at -1
    vmax       = 1      # anchor the colour scale maximum at +1
)

plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()
# Out:
#               PricePerItem  Quantity  TotalPrice
# PricePerItem          1.00      0.48        0.72
# Quantity              0.48      1.00        0.95
# TotalPrice            0.72      0.95        1.00

# %% [markdown]
# #### 9️⃣ Key Insights Summary
# > Pulls together the most important numbers discovered above.

# %%
# idxmax() — returns the INDEX (label) of the row with the highest value
# Used here to find the name of the best item / top payment method / busiest hour

best_item  = df_2.groupby('Item')['TotalPrice'].sum().idxmax()              # item with highest total revenue
best_pay   = df_2.groupby('PaymentMethod')['TotalPrice'].sum().idxmax()     # payment method with highest revenue
busy_hour  = df_2.groupby('Hour')['TransactionID'].count().idxmax()         # hour with most transactions

print('=' * 50)
print('  ☕  COFFEE SHOP — EDA SUMMARY')
print('=' * 50)
print(f'  Total transactions : {len(df_2)}')
print(f'  Total revenue      : ${df_2["TotalPrice"].sum():.2f}')   # .sum() adds all TotalPrice values
print(f'  Avg order value    : ${df_2["TotalPrice"].mean():.2f}')  # .mean() divides sum by count
print(f'  Best-selling item  : {best_item}')
print(f'  Top payment method : {best_pay}')
print(f'  Busiest hour       : {busy_hour}:00')
print('=' * 50)
# Out:
# ==================================================
#   ☕  COFFEE SHOP — EDA SUMMARY
# ==================================================
#   Total transactions : 21
#   Total revenue      : $105.60
#   Avg order value    : $5.03
#   Best-selling item  : Latte
#   Top payment method : Cash
#   Busiest hour       : 8:00
# ==================================================

# %% [markdown]
# ***

# %% [markdown]
# ***
