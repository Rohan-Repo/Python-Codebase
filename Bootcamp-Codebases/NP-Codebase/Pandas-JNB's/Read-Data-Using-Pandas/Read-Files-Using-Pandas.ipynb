# %% [markdown]
# ### Install Pandas if not already installed

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Import pandas

# %%
import pandas as pd

# %% [markdown]
# ### Read Different Types of Files

# %% [markdown]
# #### .csv File

# %%
df_csv = pd.read_csv( 'transactions.csv' )
df_csv
# Out:
#   TransactionID        Date      Time        Item  Quantity  PricePerItem  \
# 0        TX1001  2025-09-08  08:15:23  Cappuccino       1.0          3.50
# 1        TX1002  2025-09-01  08:22:11       Latte       2.0          4.00
# 2        TX1003  2025-09-12  08:35:46    Espresso       1.0          2.75
# 3        TX1004  2025-09-03  08:50:39   Croissant       1.0          2.50
# 4        TX1005  2025-09-07  09:00:02   Americano       1.0          3.00
# 5        TX1006  2025-09-02  09:05:55       Mocha       NaN          4.25
# 6        TX1007  2025-09-15  09:15:08         Tea       1.0           NaN
# 7        TX1008  2025-09-05  09:30:42       Latte       1.0          4.00
# 8        TX1009  2025-09-04  09:45:14       Bagel       1.0          2.75
# 9        TX1010  2025-09-10  10:00:27  Cappuccino       2.0          3.50
#
#    TotalPrice PaymentMethod
# 0        3.50   Credit Card
# 1        8.00          Cash
# 2        2.75    Mobile Pay
# 3        2.50   Credit Card
# ...

# %% [markdown]
# #### .xlsx File

# %%
df_xls = pd.read_excel( 'quotes_scraped.xlsx' )
df_xls
# Out:
#                                           Quote Text             Author  \
# 0  â€œThe world as we have created it is a proces...    Albert Einstein
# 1  â€œIt is our choices, Harry, that show what we...       J.K. Rowling
# 2  â€œThere are only two ways to live your life. ...    Albert Einstein
# 3  â€œThe person, be it gentleman or lady, who ha...        Jane Austen
# 4  â€œImperfection is beauty, madness is genius a...     Marilyn Monroe
# 5  â€œTry not to become a man of success. Rather ...    Albert Einstein
# 6  â€œIt is better to be hated for what you are t...        AndrÃ© Gide
# 7  â€œI have not failed. I've just found 10,000 w...   Thomas A. Edison
# 8  â€œA woman is like a tea bag; you never know h...  Eleanor Roosevelt
# 9  â€œA day without sunshine is like, you know, n...       Steve Martin
#
#                                            Tags
# 0        change, deep-thoughts, thinking, world
# 1                            abilities, choices
# ...

# %% [markdown]
# #### .json File

# %%
df_json = pd.read_json( 'users.json' )
df_json
# Out:
#   firstName lastName  age driversLicenceNumber  isProgrammer  isTester  \
# 0      John      Doe   25                 None          True     False
# 1      Jane      Doe   30          987-654-321         False      True
#
#           emailAddress     phoneNumber country      city        address
# 0    JohnDoe@gmail.com  (987) 654-3210     USA  New York   123 Main St.
# 1  JaneDoe@outlook.com  (123) 456-7890  Canada   Toronto  987 Yonge St.

# %% [markdown]
# ***
