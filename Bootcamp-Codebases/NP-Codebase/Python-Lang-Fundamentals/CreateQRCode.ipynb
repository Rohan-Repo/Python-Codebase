# %% [markdown]
# ### Install the QR Code module

# %%
#  pip install qrcode

# %% [markdown]
# ### Import Libraries

# %%
import os
import qrcode

# %%
img = qrcode.make( 'https://www.wikihow.com/Install-Python' )

img.save( 'qr.png', 'PNG' )

# %% [markdown]
# ***
