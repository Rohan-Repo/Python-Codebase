# %% [markdown]
# ### Greet User

# %%
import time

print( 'Current Time: ', time.asctime() )

time_in_hours = int(time.strftime('%H'))

print( 'Greet User:' )

time.sleep ( 1 )

if time_in_hours>6 and time_in_hours<=11:
    print( '\t Good Morning' )
elif time_in_hours == 12:
    print( '\t Happy Noon' )
elif time_in_hours>=13 and time_in_hours<=15:
    print( '\t Good Afternoon' )
elif time_in_hours>=16 and time_in_hours <=21:
    print( '\t Good Evening' )
else:
    print( '\t Good Night' )
# Out:
# Current Time:  Thu May 21 15:18:57 2026
# Greet User:
# 	 Good Afternoon
