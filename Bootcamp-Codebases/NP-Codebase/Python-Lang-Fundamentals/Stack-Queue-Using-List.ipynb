# %%
import time

# %% [markdown]
# ### Stack Using List

# %%
# Stack using List
stackList = [ 'Shell Scripting', 'Enterprise Infrastructure' ]
print( '\nOriginal Stack : ', stackList )

print( 'PUSH - Add to the Last or append()' )
stackList.append( 'Linux Kernel' )
print( 'After Book #1 : ', stackList )
stackList.append( 'Windows OS' )
print( 'After Book #2 : ', stackList )

print( 'POP - Remove from top of the Stack or pop()' )
for i in range( len(stackList)+1 ):
    print( 'Round #:', i, ' : ', stackList )
    if len(stackList) != 0 :
        stackList.pop()
        time.sleep( 1 )
# Out:
# Original Stack :  ['Shell Scripting', 'Enterprise Infrastructure']
# PUSH - Add to the Last or append()
# After Book #1 :  ['Shell Scripting', 'Enterprise Infrastructure', 'Linux Kernel']
# After Book #2 :  ['Shell Scripting', 'Enterprise Infrastructure', 'Linux Kernel', 'Windows OS']
# POP - Remove from top of the Stack or pop()
# Round #: 0  :  ['Shell Scripting', 'Enterprise Infrastructure', 'Linux Kernel', 'Windows OS']
# Round #: 1  :  ['Shell Scripting', 'Enterprise Infrastructure', 'Linux Kernel']
# Round #: 2  :  ['Shell Scripting', 'Enterprise Infrastructure']
# Round #: 3  :  ['Shell Scripting']
# Round #: 4  :  []

# %% [markdown]
# ***

# %% [markdown]
# ### Queue using List

# %%
# Queue using List
queueList = [ 'Jessica', 'Harvey', 'Louis' ]
print( 'Original Queue : ', queueList )

print( 'Enqueue - Add to the Last or append()' )
queueList.append( 'Mike' )
print( 'After Person #1 : ', queueList )
queueList.append( 'Robert' )
print( 'After Person #2 : ', queueList )

print( 'Dequeue - Remove the first or pop(0)' )
for i in range( len(queueList)+1 ):
    print( 'Round #:', i, ' : ', queueList )
    if len(queueList) != 0 :
        queueList.pop( 0 )
        time.sleep( 1 )
# Out:
# Original Queue :  ['Jessica', 'Harvey', 'Louis']
# Enqueue - Add to the Last or append()
# After Person #1 :  ['Jessica', 'Harvey', 'Louis', 'Mike']
# After Person #2 :  ['Jessica', 'Harvey', 'Louis', 'Mike', 'Robert']
# Dequeue - Remove the first or pop(0)
# Round #: 0  :  ['Jessica', 'Harvey', 'Louis', 'Mike', 'Robert']
# Round #: 1  :  ['Harvey', 'Louis', 'Mike', 'Robert']
# Round #: 2  :  ['Louis', 'Mike', 'Robert']
# Round #: 3  :  ['Mike', 'Robert']
# Round #: 4  :  ['Robert']
# Round #: 5  :  []

# %% [markdown]
# ***
