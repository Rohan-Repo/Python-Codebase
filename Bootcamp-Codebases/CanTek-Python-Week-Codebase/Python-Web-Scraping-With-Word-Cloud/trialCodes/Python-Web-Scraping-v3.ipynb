# %% [markdown]
# #### Importing Required Libraries

# %%
import pandas as pd
from bs4 import BeautifulSoup
from requests_html import HTMLSession
from requests_html import AsyncHTMLSession
import matplotlib.pyplot as plt

# %% [markdown]
# *****

# %%
from serpapi import GoogleSearch

params = {
  "engine": "google_jobs",
  "google_domain": "google.ca",
  "q": "Data Analyst",
  "hl": "en",
  "gl": "ca",
  "location": "Canada",
  "api_key": "48597aec65b318e46eb09c5257fa9826ce0cdd8b31b6c182181304742217bbb3"
}

search = GoogleSearch(params)
dataAnalystResults = search.get_dict()

df_dataAnalyst_results = pd.DataFrame( dataAnalystResults )

df_dataAnalyst_results.to_csv('Data-Analyst-Results.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 16
#      13 search = GoogleSearch(params)
#      14 dataAnalystResults = search.get_dict()
# ---> 16 df_dataAnalyst_results = pd.DataFrame( dataAnalystResults )
#      18 df_dataAnalyst_results.to_csv('Data-Analyst-Results.csv', index=False)
#
# File C:\Python311\Lib\site-packages\pandas\core\frame.py:663, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     657     mgr = self._init_mgr(
#     658         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     659     )
#     661 elif isinstance(data, dict):
#     662     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 663     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     664 elif isinstance(data, ma.MaskedArray):
#     665     import numpy.ma.mrecords as mrecords
# ...

# %%
dataAnalystResults
# Out:
# {'search_metadata': {'id': '64dfa8082d5b122162883267',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/f2bc7962bfd64950/64dfa8082d5b122162883267.json',
#   'created_at': '2023-08-18 17:19:04 UTC',
#   'processed_at': '2023-08-18 17:19:04 UTC',
#   'google_jobs_url': 'https://www.google.ca/search?q=Data+Analyst&ibp=htl;jobs&uule=w+CAIQICIGQ2FuYWRh&hl=en&gl=ca',
#   'raw_html_file': 'https://serpapi.com/searches/f2bc7962bfd64950/64dfa8082d5b122162883267.html',
#   'total_time_taken': 2.33},
#  'search_parameters': {'q': 'Data Analyst',
#   'engine': 'google_jobs',
#   'location_requested': 'Canada',
#   'location_used': 'Canada',
#   'google_domain': 'google.ca',
#   'hl': 'en',
#   'gl': 'ca'},
#  'jobs_results': [{'title': 'Data Analyst',
#    'company_name': 'Peroptyx',
#    'location': '  Canada   ',
#    'via': 'via LinkedIn',
# ...

# %%
dataRes = search.get_dictionary()

df_2 = pd.DataFrame.from_dict( dataRes, orient='columns' )

df_2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 3
#       1 dataRes = search.get_dictionary()
# ----> 3 df_2 = pd.DataFrame.from_dict( dataRes, orient='columns' )
#       5 df_2
#
# File C:\Python311\Lib\site-packages\pandas\core\frame.py:1763, in DataFrame.from_dict(cls, data, orient, dtype, columns)
#    1757     raise ValueError(
#    1758         f"Expected 'index', 'columns' or 'tight' for orient parameter. "
#    1759         f"Got '{orient}' instead"
#    1760     )
#    1762 if orient != "tight":
# -> 1763     return cls(data, index=index, columns=columns, dtype=dtype)
#    1764 else:
#    1765     realdata = data["data"]
#
# File C:\Python311\Lib\site-packages\pandas\core\frame.py:663, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     657     mgr = self._init_mgr(
# ...

# %%
from serpapi import GoogleSearch

params = {
  "engine": "google_jobs",
  "google_domain": "google.ca",
  "q": "Full Stack Developer",
  "hl": "en",
  "gl": "ca",
  "location": "Canada",
  "api_key": "48597aec65b318e46eb09c5257fa9826ce0cdd8b31b6c182181304742217bbb3"
}

search = GoogleSearch(params)
fullStackDevResults = search.get_dict()

fullStackDevResults
# Out:
# {'search_metadata': {'id': '64dfaa37a1b42331f000f810',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/379617db085d1472/64dfaa37a1b42331f000f810.json',
#   'created_at': '2023-08-18 17:28:23 UTC',
#   'processed_at': '2023-08-18 17:28:23 UTC',
#   'google_jobs_url': 'https://www.google.ca/search?q=Full+Stack+Developer&ibp=htl;jobs&uule=w+CAIQICIGQ2FuYWRh&hl=en&gl=ca',
#   'raw_html_file': 'https://serpapi.com/searches/379617db085d1472/64dfaa37a1b42331f000f810.html',
#   'total_time_taken': 6.1},
#  'search_parameters': {'q': 'Full Stack Developer',
#   'engine': 'google_jobs',
#   'location_requested': 'Canada',
#   'location_used': 'Canada',
#   'google_domain': 'google.ca',
#   'hl': 'en',
#   'gl': 'ca'},
#  'jobs_results': [{'title': 'Senior Full-Stack Developer (Remote Canada)',
#    'company_name': 'Autodesk',
#    'location': '  Canada   ',
#    'via': 'via LinkedIn',
# ...

# %%
from serpapi import GoogleSearch

params = {
  "engine": "google_jobs",
  "google_domain": "google.ca",
  "q": "Python Engineer",
  "hl": "en",
  "gl": "ca",
  "location": "Canada",
  "api_key": "48597aec65b318e46eb09c5257fa9826ce0cdd8b31b6c182181304742217bbb3"
}

search = GoogleSearch(params)
pythonDevResults = search.get_dict()

pythonDevResults
# Out:
# {'search_metadata': {'id': '64dfaa607f83616102024bce',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/997e1478e89c6dbd/64dfaa607f83616102024bce.json',
#   'created_at': '2023-08-18 17:29:04 UTC',
#   'processed_at': '2023-08-18 17:29:04 UTC',
#   'google_jobs_url': 'https://www.google.ca/search?q=Python+Engineer&ibp=htl;jobs&uule=w+CAIQICIGQ2FuYWRh&hl=en&gl=ca',
#   'raw_html_file': 'https://serpapi.com/searches/997e1478e89c6dbd/64dfaa607f83616102024bce.html',
#   'total_time_taken': 1.3},
#  'search_parameters': {'q': 'Python Engineer',
#   'engine': 'google_jobs',
#   'location_requested': 'Canada',
#   'location_used': 'Canada',
#   'google_domain': 'google.ca',
#   'hl': 'en',
#   'gl': 'ca'},
#  'jobs_results': [{'title': 'Junior Software Engineer (Python, Linux and Automation)',
#    'company_name': 'iVedha Inc.',
#    'location': '  Canada   ',
#    'via': 'via LinkedIn',
# ...
